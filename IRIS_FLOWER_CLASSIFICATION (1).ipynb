# %% [markdown]
# # ***IRIS FLOWER CLASSIFICATION***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Project/2-IRIS FLOWER CLASSIFICATION/IRIS (1).csv')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.shape
# Out:
# (150, 5)

# %%
data = data.drop_duplicates()
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  147 non-null    float64
#  1   sepal_width   147 non-null    float64
#  2   petal_length  147 non-null    float64
#  3   petal_width   147 non-null    float64
#  4   species       147 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.9+ KB

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.856463     3.055782      3.780272     1.208844
# std        0.829100     0.437009      1.759111     0.757874
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.isna().any()
# Out:
# sepal_length    False
# sepal_width     False
# petal_length    False
# petal_width     False
# species         False
# dtype: bool

# %%
list = ['sepal_length','sepal_width','petal_length','petal_width','species']

for i in list:
  print(data[i].unique(),i)
  print('-----------------------')
# Out:
# [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9] sepal_length
# -----------------------
# [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6] sepal_width
# -----------------------
# [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2] petal_length
# -----------------------
# [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3] petal_width
# -----------------------
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica'] species
# -----------------------

# %%
list = ['sepal_length','sepal_width','petal_length','petal_width','species']

for i in list:
  print(data[i].value_counts())
  print('-----------------------')
# Out:
# 5.0    10
# 5.1     9
# 6.3     9
# 6.7     8
# 5.7     8
# 5.5     7
# 6.4     7
# 5.8     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 4.9     4
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal_length, dtype: int64
# -----------------------
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    10
# 2.9    10
# 2.5     8
# 2.7     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepal_width, dtype: int64
# -----------------------
# 1.4    12
# 1.5    12
# 4.5     8
# 1.6     7
# 5.1     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# ...

# %% [markdown]
# **Encoding categorical values in the output column to numerical values.**

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
data["species"]=label.fit_transform(data["species"])
# Out:
# <ipython-input-12-b3409d1aad1f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["species"]=label.fit_transform(data["species"])

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [147 rows x 5 columns]

# %%
data["species"].value_counts()
# Out:
# 1    50
# 2    49
# 0    48
# Name: species, dtype: int64

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species           int64
# dtype: object

# %%
sns.heatmap(data.corr(),annot=True,linewidth=0.5)
# Out:
# <Axes: >

# %% [markdown]
# **OBSERVATION**
#
#
# *   Highest correlation is between petal length and petal width and also between petal width and species.

# %% [markdown]
# # **Spliting Independent and Dependent Features**

# %%
x = data.iloc[:,:4]
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [147 rows x 4 columns]

# %%
y = data['species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: species, Length: 147, dtype: int64

# %% [markdown]
# # **TRAIN-TEST SPLITTING**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# **STANDARDIZATION**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# # **MODEL CREATION**

# %% [markdown]
# **1) K-NEAREST NEIGHBOR (KNN) :**

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(x_train,y_train)

y_pred1=knn_model.predict(x_test)
y_pred1
# Out:
# array([0, 0, 0, 2, 2, 1, 0, 0, 2, 0, 0, 1, 2, 1, 1, 1, 0, 1, 2, 0, 1, 0,
#        2, 1, 2, 0, 2, 1, 2, 2])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
result = confusion_matrix(y_test,y_pred1)
print(result)
labels=[0,1,2]
cmd = ConfusionMatrixDisplay(result,display_labels=labels)
# Out:
# [[11  0  0]
#  [ 0  9  1]
#  [ 0  0  9]]

# %%
cmd.plot()

# %%
from sklearn.metrics import accuracy_score,classification_report

print('Accuracy: ',accuracy_score(y_test,y_pred1)*100,'\n')
print(classification_report(y_test,y_pred1))
# Out:
# Accuracy:  96.66666666666667
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.90      0.95        10
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
training_score = knn_model.score(x_train,y_train)
training_score
# Out:
# 0.9658119658119658

# %% [markdown]
# **2) SUPPORT VECTOR MACHINE ALGORITHM :**

# %%
from sklearn.svm import SVC

sv_model=SVC()
sv_model.fit(x_train,y_train)
y_pred2=sv_model.predict(x_test)
y_pred2
# Out:
# array([0, 0, 0, 2, 2, 1, 0, 0, 2, 0, 0, 1, 2, 1, 1, 1, 0, 1, 2, 0, 1, 0,
#        2, 1, 2, 0, 2, 1, 1, 2])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
result = confusion_matrix(y_test,y_pred2)
print(result)
labels=[0,1,2]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
# Out:
# [[11  0  0]
#  [ 0 10  0]
#  [ 0  0  9]]

# %%
cmd.plot()

# %%
from sklearn.metrics import accuracy_score,classification_report

print('Accuracy: ',accuracy_score(y_test,y_pred2)*100,'\n')
print(classification_report(y_test,y_pred2))
# Out:
# Accuracy:  100.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         9
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
training_score = sv_model.score(x_train,y_train)
training_score
# Out:
# 0.9658119658119658

# %% [markdown]
# **3) LOGISTIC REGRESSION :**

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(x_train,y_train)
y_pred3 = lr_model.predict(x_test)
y_pred3
# Out:
# array([0, 0, 0, 2, 2, 1, 0, 0, 2, 0, 0, 1, 2, 1, 1, 1, 0, 1, 2, 0, 1, 0,
#        2, 1, 2, 0, 2, 1, 1, 2])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
result=confusion_matrix(y_test,y_pred3)
print(result)
labels=[0,1,2]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
# Out:
# [[11  0  0]
#  [ 0 10  0]
#  [ 0  0  9]]

# %%
cmd.plot()

# %%
from sklearn.metrics import accuracy_score,classification_report

print('Accuracy: ',accuracy_score(y_test,y_pred3)*100,'\n')
print(classification_report(y_test,y_pred3))
# Out:
# Accuracy:  100.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00         9
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
training_score = lr_model.score(x_train,y_train)
training_score
# Out:
# 0.9658119658119658

# %% [markdown]
# **4) DECISION TREE :**

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model=DecisionTreeClassifier(max_depth = 5,criterion = 'entropy')
tree_model.fit(x_train,y_train)
y_pred4 = tree_model.predict(x_test)
y_pred4
# Out:
# array([0, 0, 0, 2, 2, 1, 0, 0, 2, 0, 0, 1, 1, 1, 1, 1, 0, 2, 2, 0, 1, 0,
#        2, 1, 2, 0, 2, 1, 2, 2])

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
result=confusion_matrix(y_test,y_pred4)
print(result)
labels=[0,1,2]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
# Out:
# [[11  0  0]
#  [ 0  8  2]
#  [ 0  1  8]]

# %%
cmd.plot()

# %%
from sklearn.metrics import accuracy_score,classification_report

print('Accuracy: ',accuracy_score(y_test,y_pred4)*100,'\n')
print(classification_report(y_test,y_pred4))
# Out:
# Accuracy:  90.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.89      0.80      0.84        10
#            2       0.80      0.89      0.84         9
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.89        30
# weighted avg       0.90      0.90      0.90        30

# %%
training_score = tree_model.score(x_train,y_train)
training_score
# Out:
# 1.0

# %% [markdown]
# # **PREDICTION**

# %%
sv_model.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array([2])

# %%
lr_model.predict([[6.7,3.0,5.2,2.3]])
# Out:
# array([2])

# %% [markdown]
# # **CONCLUSION**
#
#
#
# *   Here, we have 2 models with 100% accuracy, SVM model and logistic regression model.Therefore these both are best models

# %% [markdown]
# # ***`Thank You`***
